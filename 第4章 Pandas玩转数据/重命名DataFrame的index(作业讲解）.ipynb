# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
csv_input = '/Users/LING/movie_metadata.csv'

# %%
pd.read_csv(csv_input).head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
pd.read_csv(csv_input).head()[['imdb_score','director_name','movie_title']]
# Out:
#    imdb_score      director_name  \
# 0         7.9      James Cameron
# 1         7.1     Gore Verbinski
# 2         6.8         Sam Mendes
# 3         8.5  Christopher Nolan
# 4         7.1        Doug Walker
#
#                                          movie_title
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# 4  Star Wars: Episode VII - The Force Awakens    ...

# %%
pd.read_csv(csv_input)[['imdb_score','director_name','movie_title']].sort_values("imdb_score",ascending=False)
# Out:
#       imdb_score           director_name  \
# 2765         9.5          John Blanchard
# 1937         9.3          Frank Darabont
# 3466         9.2    Francis Ford Coppola
# 4409         9.1          John Stockwell
# 2824         9.1                     NaN
# 3207         9.1                     NaN
# 66           9.0       Christopher Nolan
# 2837         9.0    Francis Ford Coppola
# 3481         9.0                     NaN
# 339          8.9           Peter Jackson
# 4822         8.9            Sidney Lumet
# 4498         8.9            Sergio Leone
# 3355         8.9       Quentin Tarantino
# 1874         8.9        Steven Spielberg
# 683          8.8           David Fincher
# 836          8.8         Robert Zemeckis
# 270          8.8           Peter Jackson
# 2051         8.8          Irvin Kershner
# 97           8.8       Christopher Nolan
# 1842         8.8                     NaN
# 459          8.8                     NaN
# 1620         8.7                     NaN
# ...

# %%
pd.read_csv(csv_input)[['imdb_score','director_name','movie_title']].sort_values("imdb_score",ascending=False).to_csv('imdb.csv')

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !more imdb.csv
# Out:
# ,imdb_score,director_name,movie_title
# 2765,9.5,John Blanchard,Towering InfernoÂ
# 1937,9.3,Frank Darabont,The Shawshank RedemptionÂ
# 3466,9.2,Francis Ford Coppola,The GodfatherÂ
# 4409,9.1,John Stockwell,Kickboxer: VengeanceÂ
# 2824,9.1,,DekalogÂ
# 3207,9.1,,DekalogÂ
# 66,9.0,Christopher Nolan,The Dark KnightÂ
# 2837,9.0,Francis Ford Coppola,The Godfather: Part IIÂ
# 3481,9.0,,FargoÂ
# 339,8.9,Peter Jackson,The Lord of the Rings: The Return of the KingÂ
# 4822,8.9,Sidney Lumet,12 Angry MenÂ
# 4498,8.9,Sergio Leone,"The Good, the Bad and the UglyÂ "
# 3355,8.9,Quentin Tarantino,Pulp FictionÂ
# 1874,8.9,Steven Spielberg,Schindler's ListÂ
# 683,8.8,David Fincher,Fight ClubÂ
# 836,8.8,Robert Zemeckis,Forrest GumpÂ
# 270,8.8,Peter Jackson,The Lord of the Rings: The Fellowship of the RingÂ
# 2051,8.8,Irvin Kershner,Star Wars: Episode V - The Empire Strikes BackÂ
# 97,8.8,Christopher Nolan,InceptionÂ
# 1842,8.8,,It's Always Sunny in PhiladelphiaÂ
# 459,8.8,,DaredevilÂ
# ...
