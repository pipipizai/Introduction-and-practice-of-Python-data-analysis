# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
s1 = Series(np.random.randn(1000)).cumsum()

# %%
s = Series([1,2,3,4,5])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.cumsum()
# Out:
# 0     1
# 1     3
# 2     6
# 3    10
# 4    15
# dtype: int64

# %%
s1.plot()

# %%
s1.plot(kind='bar')

# %%
s1 = Series(np.random.randn(10)).cumsum()

# %%
s1.plot(kind='bar')

# %%
s1.plot(kind='line')

# %%
s1.plot(kind='line',grid=True)

# %%
s1.plot(kind='line',grid=True,label='S1')

# %%
s1.plot(kind='line',grid=True,label='S1')
plt.legend()

# %%
s1.plot(kind='line',grid=True,label='S1',title='This is Series')
plt.legend()

# %%
s1.plot(kind='line',grid=True,label='S1',title='This is Series',style='--')
plt.legend()

# %%
s1 = Series(np.random.randn(1000)).cumsum()
s2 = Series(np.random.randn(1000)).cumsum()

# %%
s1.plot(kind='line',grid=True,label='S1',title='This is Series')
s2.plot(label='S2')

# %%
s1.plot(kind='line',grid=True,label='S1',title='This is Series')
s2.plot(label='S2')
plt.legend()

# %%
fig, ax=plt.subplots(2,1)
ax[0].plot(s1)
ax[1].plot(s2)

# %%
ax
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021DB74572B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000021DB7470DD8>],
#       dtype=object)

# %%
fig, ax=plt.subplots(2,1)
s1.plot(ax=ax[0],label='S1')
s2.plot(ax=ax[1],label='S2')

# %%
fig, ax=plt.subplots(2,1)
s1[0:10].plot(ax=ax[0],label='S1',kind='bar')
s2.plot(ax=ax[1],label='S2')
