# %%
# 基本信息
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# 股票数据的读取
import pandas_datareader as pdr

# 可视化
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# time
from datetime import datetime

# %%
start = datetime(2015,9,20)
alibaba = pdr.get_data_yahoo('BABA', start = start)
amazon = pdr.get_data_yahoo('AMZN', start = start)

# %%
alibaba.to_csv('/Users/LING/BABA.csv')
amazon.to_csv('/Users/LING/AMZNz.csv')

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-09-21  66.400002  62.959999  65.379997  63.900002  22355100  63.900002
# 2015-09-22  63.270000  61.580002  62.939999  61.900002  14897900  61.900002
# 2015-09-23  62.299999  59.680000  61.959999  60.000000  22684600  60.000000
# 2015-09-24  60.340000  58.209999  59.419998  59.919998  20645700  59.919998
# 2015-09-25  60.840000  58.919998  60.630001  59.240002  17009100  59.240002

# %%
alibaba['Adj Close'].plot(legend=True)

# %%
alibaba['Volume'].plot(legend=True)

# %%
alibaba['Adj Close'].plot(legend=True)
amazon['Adj Close'].plot(legend=True)

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-09-21  66.400002  62.959999  65.379997  63.900002  22355100  63.900002
# 2015-09-22  63.270000  61.580002  62.939999  61.900002  14897900  61.900002
# 2015-09-23  62.299999  59.680000  61.959999  60.000000  22684600  60.000000
# 2015-09-24  60.340000  58.209999  59.419998  59.919998  20645700  59.919998
# 2015-09-25  60.840000  58.919998  60.630001  59.240002  17009100  59.240002

# %%
alibaba['high-low'] = alibaba['High'] - alibaba['Low']

# %%
alibaba.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 2015-09-21  66.400002  62.959999  65.379997  63.900002  22355100  63.900002
# 2015-09-22  63.270000  61.580002  62.939999  61.900002  14897900  61.900002
# 2015-09-23  62.299999  59.680000  61.959999  60.000000  22684600  60.000000
# 2015-09-24  60.340000  58.209999  59.419998  59.919998  20645700  59.919998
# 2015-09-25  60.840000  58.919998  60.630001  59.240002  17009100  59.240002
#
#             high-low
# Date
# 2015-09-21  3.440002
# 2015-09-22  1.689999
# 2015-09-23  2.619999
# 2015-09-24  2.130001
# 2015-09-25  1.920002

# %%
alibaba['high-low'].plot()

# %%
# daily return
alibaba['Adj Close'].pct_change()
# Out:
# Date
# 2015-09-21         NaN
# 2015-09-22   -0.031299
# 2015-09-23   -0.030695
# 2015-09-24   -0.001333
# 2015-09-25   -0.011348
# 2015-09-28   -0.031229
# 2015-09-29    0.007493
# 2015-09-30    0.019889
# 2015-10-01   -0.001696
# 2015-10-02    0.073552
# 2015-10-05    0.011551
# 2015-10-06   -0.000156
# 2015-10-07    0.036921
# 2015-10-08    0.021424
# 2015-10-09    0.014919
# 2015-10-12    0.023141
# 2015-10-13   -0.008819
# 2015-10-14   -0.016360
# 2015-10-15    0.047272
# 2015-10-16    0.002926
# 2015-10-19    0.009168
# 2015-10-20   -0.011838
# 2015-10-21   -0.032177
# 2015-10-22    0.021733
# 2015-10-23    0.065221
# 2015-10-26    0.009653
# 2015-10-27    0.040472
# 2015-10-28    0.036631
# 2015-10-29   -0.001579
# 2015-10-30    0.019582
#                 ...
# 2019-07-15    0.026202
# 2019-07-16    0.003977
# 2019-07-17    0.003617
# 2019-07-18   -0.011555
# 2019-07-19    0.001100
# 2019-07-22    0.005838
# 2019-07-23    0.023506
# 2019-07-24    0.003257
# ...

# %%
alibaba['daily_return'] = alibaba['Adj Close'].pct_change()

# %%
alibaba['daily_return'].plot()

# %%
alibaba['daily_return'].plot(figsize=(10,4))

# %%
alibaba['daily_return'].plot(figsize=(10,4),linestyle='--')

# %%
alibaba['daily_return'].plot(figsize=(10,4),linestyle='--',marker='o')

# %%
alibaba['daily_return'].plot(kind='hist')

# %%
sns.distplot(alibaba['daily_return'].dropna(),bins=100,color='purple')
